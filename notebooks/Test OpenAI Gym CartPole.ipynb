# %% [markdown]
# Run to test the install of the OpenAI gym.
#
# For the rendering, I followed the solution for this question.
# https://stackoverflow.com/questions/40195740/how-to-run-openai-gym-render-over-a-server
#
# Of note is the need to run the notebook server via this command to avoid some cryptic exceptions:
# ```
# xvfb-run -s "-screen 0 1400x900x24" jupyter notebook
# ```

# %%
import gym

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

# %%
env = gym.make("CartPole-v0")
# Out:
# [2018-02-01 05:41:48,488] Making new env: CartPole-v0

# %%
env.reset()
# Out:
# array([ 0.01550608, -0.02044833,  0.04138387,  0.01931981])

# %%
def show_state(env, step=0, info=""):
    """Render an image of the environment"""
    plt.figure(3)
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title(f"{env.spec.id} | Step: {step} {info}")
    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
env.reset()

for step in range(100):
    env.step(env.action_space.sample())
    show_state(env, step=step)
# Second image appears after the loop completes. I'm unsure why it does this.
